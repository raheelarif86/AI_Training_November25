# %% [markdown]
# <a href="https://colab.research.google.com/github/raheelarif86/AI_Training_November25/blob/main/Copy_of_Weather_abudhabhi_5yr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------------------------------------
# Advanced 5-Year Abu Dhabi Weather Data (Open-Meteo Archive)
# -----------------------------------------------------------
import pandas as pd
import requests
from datetime import date

# Abu Dhabi coordinates
LAT, LON = 24.4539, 54.3773

# Date range (last 5 years)
start_date = "2019-01-01"
end_date = date.today().strftime("%Y-%m-%d")

# Request multiple variables
url = (
    "https://archive-api.open-meteo.com/v1/archive?"
    f"latitude={LAT}&longitude={LON}"
    f"&start_date={start_date}&end_date={end_date}"
    "&daily=temperature_2m_max,temperature_2m_min,temperature_2m_mean,"
    "apparent_temperature_max,apparent_temperature_min,"
    "precipitation_sum,rain_sum,snowfall_sum,precipitation_hours,"
    "windspeed_10m_max,windgusts_10m_max,winddirection_10m_dominant,"
    "shortwave_radiation_sum,et0_fao_evapotranspiration,"
    "sunshine_duration,pressure_msl_min,pressure_msl_max"
    "&timezone=Asia/Dubai"
)

# Fetch data
response = requests.get(url)
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data["daily"])
df["time"] = pd.to_datetime(df["time"])

# Save dataset
df.to_csv("abu_dhabi_weather_5yrs_full.csv", index=False)
print(f"✅ Saved {len(df)} days of data to abu_dhabi_weather_5yrs_full.csv")

# Preview
df.head()
# Out:
# ✅ Saved 2514 days of data to abu_dhabi_weather_5yrs_full.csv
#         time  temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# 0 2019-01-01                25.0                17.5                 21.5
# 1 2019-01-02                26.7                18.6                 22.0
# 2 2019-01-03                29.3                17.5                 22.8
# 3 2019-01-04                25.1                18.6                 21.8
# 4 2019-01-05                23.4                19.2                 21.4
#
#    apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 0                      25.0                      18.1                0.0
# 1                      26.3                      19.5                0.0
# 2                      28.0                      17.2                0.0
# 3                      25.7                      17.7                0.0
# 4                      22.1                      17.6                0.0
#
#    rain_sum  snowfall_sum  precipitation_hours  windspeed_10m_max  \
# 0       0.0           0.0                  0.0               14.6
# 1       0.0           0.0                  0.0               16.2
# 2       0.0           0.0                  0.0               18.6
# 3       0.0           0.0                  0.0               30.5
# 4       0.0           0.0                  0.0               30.0
#
#    windgusts_10m_max  winddirection_10m_dominant  shortwave_radiation_sum  \
# 0               28.4                          26                    15.02
# 1               28.4                          56                    15.09
# 2               33.1                         141                    15.05
# 3               44.3                         297                    14.80
# 4               43.9                         314                    15.54
#
#    et0_fao_evapotranspiration  sunshine_duration  pressure_msl_min  \
# 0                        3.09           33226.16            1019.4
# 1                        3.29           33415.02            1018.5
# 2                        3.65           33058.73            1017.6
# 3                        3.76           33289.27            1018.6
# 4                        4.20           33609.33            1018.3
#
#    pressure_msl_max
# 0            1023.4
# 1            1022.3
# 2            1022.4
# 3            1021.3
# 4            1022.1

# %%
df.head()
# Out:
#         time  temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# 0 2019-01-01                25.0                17.5                 21.5
# 1 2019-01-02                26.7                18.6                 22.0
# 2 2019-01-03                29.3                17.5                 22.8
# 3 2019-01-04                25.1                18.6                 21.8
# 4 2019-01-05                23.4                19.2                 21.4
#
#    apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 0                      25.0                      18.1                0.0
# 1                      26.3                      19.5                0.0
# 2                      28.0                      17.2                0.0
# 3                      25.7                      17.7                0.0
# 4                      22.1                      17.6                0.0
#
#    rain_sum  snowfall_sum  precipitation_hours  windspeed_10m_max  \
# 0       0.0           0.0                  0.0               14.6
# 1       0.0           0.0                  0.0               16.2
# 2       0.0           0.0                  0.0               18.6
# 3       0.0           0.0                  0.0               30.5
# 4       0.0           0.0                  0.0               30.0
#
#    windgusts_10m_max  winddirection_10m_dominant  shortwave_radiation_sum  \
# 0               28.4                          26                    15.02
# 1               28.4                          56                    15.09
# 2               33.1                         141                    15.05
# 3               44.3                         297                    14.80
# 4               43.9                         314                    15.54
#
#    et0_fao_evapotranspiration  sunshine_duration  pressure_msl_min  \
# 0                        3.09           33226.16            1019.4
# 1                        3.29           33415.02            1018.5
# 2                        3.65           33058.73            1017.6
# 3                        3.76           33289.27            1018.6
# 4                        4.20           33609.33            1018.3
#
#    pressure_msl_max
# 0            1023.4
# 1            1022.3
# 2            1022.4
# 3            1021.3
# 4            1022.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2514 entries, 0 to 2513
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   time                        2514 non-null   datetime64[ns]
#  1   temperature_2m_max          2514 non-null   float64
#  2   temperature_2m_min          2514 non-null   float64
#  3   temperature_2m_mean         2514 non-null   float64
#  4   apparent_temperature_max    2514 non-null   float64
#  5   apparent_temperature_min    2514 non-null   float64
#  6   precipitation_sum           2514 non-null   float64
#  7   rain_sum                    2514 non-null   float64
#  8   snowfall_sum                2514 non-null   float64
#  9   precipitation_hours         2514 non-null   float64
#  10  windspeed_10m_max           2514 non-null   float64
#  11  windgusts_10m_max           2514 non-null   float64
#  12  winddirection_10m_dominant  2514 non-null   int64
#  13  shortwave_radiation_sum     2514 non-null   float64
#  14  et0_fao_evapotranspiration  2514 non-null   float64
#  15  sunshine_duration           2514 non-null   float64
#  16  pressure_msl_min            2514 non-null   float64
#  17  pressure_msl_max            2514 non-null   float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 353.7 KB

# %%
df.describe()
# Out:
#                                 time  temperature_2m_max  temperature_2m_min  \
# count                           2514         2514.000000         2514.000000
# mean   2022-06-10 11:59:59.999999744           33.106285           25.236993
# min              2019-01-01 00:00:00           18.300000           13.300000
# 25%              2020-09-20 06:00:00           27.300000           20.400000
# 50%              2022-06-10 12:00:00           34.100000           25.800000
# 75%              2024-02-28 18:00:00           38.400000           30.000000
# max              2025-11-18 00:00:00           46.500000           35.800000
# std                              NaN            6.577466            5.372844
#
#        temperature_2m_mean  apparent_temperature_max  \
# count          2514.000000               2514.000000
# mean             28.731146                 34.533095
# min              17.000000                 13.400000
# 25%              23.600000                 27.100000
# 50%              29.650000                 35.700000
# 75%              33.800000                 42.000000
# max              39.100000                 49.800000
# std               5.581373                  8.386427
#
#        apparent_temperature_min  precipitation_sum     rain_sum  snowfall_sum  \
# count               2514.000000        2514.000000  2514.000000        2514.0
# mean                  27.509228           0.179714     0.179714           0.0
# min                    8.500000           0.000000     0.000000           0.0
# 25%                   20.225000           0.000000     0.000000           0.0
# 50%                   28.100000           0.000000     0.000000           0.0
# 75%                   34.900000           0.000000     0.000000           0.0
# max                   42.400000          67.700000    67.700000           0.0
# std                    8.050620           2.405945     2.405945           0.0
#
#        precipitation_hours  windspeed_10m_max  windgusts_10m_max  \
# count          2514.000000        2514.000000        2514.000000
# mean              0.200875          23.138823          39.401432
# min               0.000000           9.200000          18.000000
# 25%               0.000000          18.800000          33.800000
# 50%               0.000000          22.600000          38.500000
# 75%               0.000000          26.500000          43.600000
# max              21.000000          51.200000          81.000000
# std               1.215295           6.074824           8.054137
#
#        winddirection_10m_dominant  shortwave_radiation_sum  \
# count                 2514.000000              2514.000000
# mean                   218.411695                20.990306
# min                      0.000000                 5.990000
# 25%                     71.000000                17.272500
# 50%                    291.000000                22.050000
# 75%                    319.000000                24.450000
# max                    360.000000                27.470000
# std                    128.395183                 4.286053
#
#        et0_fao_evapotranspiration  sunshine_duration  pressure_msl_min  \
# count                 2514.000000        2514.000000       2514.000000
# mean                     6.014360       37805.526838       1006.810103
# min                      2.000000        1655.320000        990.000000
# 25%                      4.580000       35746.577500       1000.100000
# 50%                      6.130000       39109.530000       1007.700000
# 75%                      7.280000       40167.452500       1013.600000
# max                     12.380000       44608.450000       1022.900000
# std                      1.744508        4698.046101          7.755879
#
#        pressure_msl_max
# count       2514.000000
# mean        1010.159228
# min          992.900000
# 25%         1003.200000
# 50%         1011.400000
# 75%         1017.300000
# max         1026.300000
# std            8.044292

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------------------------------------------------------
# 4. STEP 3 & 4: UNIVARIATE ANALYSIS AND VISUALIZATION
#
# We examine one clue at a time (Univariate Analysis) .
# -----------------------------------------------------------------------------

print("--- Univariate Analysis: temperature_2m_max ---")

# Descriptive Stats: Gather basic facts
print("\nBasic Facts (Descriptive Statistics):")
print(df['temperature_2m_max'].describe())
# The mean score should be close to 78, as observed in the analysis

# Visualization: Histogram
# Shows the distribution of scores
plt.figure(figsize=(9, 6))
sns.histplot(df['temperature_2m_max'], kde=True, bins=15, color='skyblue')
plt.title('Distribution of temperature_2m_max', fontsize=14)
plt.xlabel('temperature_2m_max')
plt.ylabel('Frequency')
plt.axvline(df['temperature_2m_max'].mean(), color='red', linestyle='--', label=f'Mean: {df["temperature_2m_max"].mean():.2f}')
plt.legend()
plt.show()

# Insight: The chart shows scores 'bunched up right around the average of 78' .
# The visual distribution should clearly show the 'little tail stretching out to the left' (left skew) .
print("-" * 50)
# Out:
# --- Univariate Analysis: temperature_2m_max ---
#
# Basic Facts (Descriptive Statistics):
# count    2514.000000
# mean       33.106285
# std         6.577466
# min        18.300000
# 25%        27.300000
# 50%        34.100000
# 75%        38.400000
# max        46.500000
# Name: temperature_2m_max, dtype: float64
# --------------------------------------------------

# %%
# -----------------------------------------------------------------------------
# 5. STEP 4: BIVARIATE ANALYSIS (Connecting the Dots)
#
# We examine two pieces of evidence together . We test  vs. Score.
# -----------------------------------------------------------------------------

print("--- Bivariate Analysis: temperature_2m_max vs. windspeed_10m_max ---")

# Scatter Plot: Look for links between Study Hours and Final Exam Score
plt.figure(figsize=(9, 6))
sns.scatterplot(x='temperature_2m_max', y='windspeed_10m_max', data=df, color='darkgreen')
plt.title('temperature_2m_max vs. windspeed_10m_max (Positive Correlation)', fontsize=14)
plt.xlabel('temperature_2m_max')
plt.ylabel('windspeed_10m_max')
plt.show()

# Observation: The dots should form a clear upward trend (positive correlation) [5].
print("Scatter plot shows a clear upward trend: more study time generally means better scores [5].")
print("-" * 50)
# Out:
# --- Bivariate Analysis: temperature_2m_max vs. windspeed_10m_max ---
# Scatter plot shows a clear upward trend: more study time generally means better scores [5].
# --------------------------------------------------

# %% [markdown]
# | **Column Name**              | **Description**                                       | **Unit**        | **Details / Notes**                                                  |
# | ---------------------------- | ----------------------------------------------------- | --------------- | -------------------------------------------------------------------- |
# | `time`                       | Date of the recorded observation                      | YYYY-MM-DD      | Represents the daily timestamp (Dubai timezone).                     |
# | `temperature_2m_max`         | Maximum air temperature at 2 meters above ground      | °C              | Daily high temperature recorded for that day.                        |
# | `temperature_2m_min`         | Minimum air temperature at 2 meters above ground      | °C              | Daily lowest temperature recorded for that day.                      |
# | `temperature_2m_mean`        | Mean air temperature at 2 meters above ground         | °C              | Average of hourly temperatures across the day.                       |
# | `apparent_temperature_max`   | Maximum “feels-like” temperature                      | °C              | Includes the effect of humidity and wind on how hot it feels.        |
# | `apparent_temperature_min`   | Minimum “feels-like” temperature                      | °C              | “Feels-like” low temperature considering humidity and wind.          |
# | `precipitation_sum`          | Total precipitation (rain + snow + other forms)       | mm              | Combined total of all precipitation types in a day.                  |
# | `rain_sum`                   | Total rainfall                                        | mm              | Portion of total precipitation that fell as liquid rain.             |
# | `snowfall_sum`               | Total snowfall                                        | cm              | Snow equivalent recorded for that day (usually 0 in Abu Dhabi).      |
# | `precipitation_hours`        | Number of hours with measurable precipitation         | hours           | Duration when precipitation occurred during the day.                 |
# | `windspeed_10m_max`          | Maximum wind speed at 10 meters above ground          | km/h            | Peak sustained wind speed observed daily.                            |
# | `windgusts_10m_max`          | Maximum wind gust at 10 meters                        | km/h            | Short-term peak gust speed (instantaneous).                          |
# | `winddirection_10m_dominant` | Dominant wind direction                               | degrees (0–360) | Average direction of prevailing winds (0° = North, 90° = East).      |
# | `shortwave_radiation_sum`    | Total shortwave solar radiation received              | MJ/m²           | Sum of solar radiation during daylight hours.                        |
# | `et0_fao_evapotranspiration` | Reference evapotranspiration (FAO-56 Penman-Monteith) | mm/day          | Proxy for potential evaporation, useful in agriculture/climate.      |
# | `sunshine_duration`          | Total sunshine duration                               | seconds         | Number of seconds with direct sunlight exposure per day.             |
# | `pressure_msl_min`           | Minimum mean sea level pressure                       | hPa             | Lowest atmospheric pressure recorded that day (sea level adjusted).  |
# | `pressure_msl_max`           | Maximum mean sea level pressure                       | hPa             | Highest atmospheric pressure recorded that day (sea level adjusted). |

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("abu_dhabi_weather_5yrs_full.csv")
df["time"] = pd.to_datetime(df["time"])

# Summary
print(df.describe().T)

# Temperature trend
plt.figure(figsize=(12,6))
plt.plot(df["time"], df["temperature_2m_mean"], label="Mean Temperature °C")
plt.title("Abu Dhabi Daily Mean Temperature (2019–2025)")
plt.xlabel("Date"); plt.ylabel("°C"); plt.legend(); plt.grid(True)
plt.show()

# Correlation matrix
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes("number").corr(), cmap="coolwarm", annot=False)
plt.title("Feature Correlation Matrix"); plt.show()

# Seasonal average temperatures
df["year"] = df["time"].dt.year
df["month"] = df["time"].dt.month
monthly_avg = df.groupby("month")["temperature_2m_mean"].mean()
plt.figure(figsize=(10,5))
monthly_avg.plot(kind="bar", color="teal")
plt.title("Average Monthly Temperature (2019–2025)")
plt.xlabel("Month"); plt.ylabel("°C"); plt.show()
# Out:
#                              count                           mean  \
# time                          2514  2022-06-10 11:59:59.999999744
# temperature_2m_max          2514.0                      33.106285
# temperature_2m_min          2514.0                      25.236993
# temperature_2m_mean         2514.0                      28.731146
# apparent_temperature_max    2514.0                      34.533095
# apparent_temperature_min    2514.0                      27.509228
# precipitation_sum           2514.0                       0.179714
# rain_sum                    2514.0                       0.179714
# snowfall_sum                2514.0                            0.0
# precipitation_hours         2514.0                       0.200875
# windspeed_10m_max           2514.0                      23.138823
# windgusts_10m_max           2514.0                      39.401432
# winddirection_10m_dominant  2514.0                     218.411695
# shortwave_radiation_sum     2514.0                      20.990306
# et0_fao_evapotranspiration  2514.0                        6.01436
# sunshine_duration           2514.0                   37805.526838
# pressure_msl_min            2514.0                    1006.810103
# pressure_msl_max            2514.0                    1010.159228
#
#                                             min                  25%  \
# time                        2019-01-01 00:00:00  2020-09-20 06:00:00
# temperature_2m_max                         18.3                 27.3
# temperature_2m_min                         13.3                 20.4
# temperature_2m_mean                        17.0                 23.6
# apparent_temperature_max                   13.4                 27.1
# apparent_temperature_min                    8.5               20.225
# precipitation_sum                           0.0                  0.0
# rain_sum                                    0.0                  0.0
# snowfall_sum                                0.0                  0.0
# precipitation_hours                         0.0                  0.0
# windspeed_10m_max                           9.2                 18.8
# windgusts_10m_max                          18.0                 33.8
# winddirection_10m_dominant                  0.0                 71.0
# shortwave_radiation_sum                    5.99              17.2725
# et0_fao_evapotranspiration                  2.0                 4.58
# sunshine_duration                       1655.32           35746.5775
# pressure_msl_min                          990.0               1000.1
# pressure_msl_max                          992.9               1003.2
#
#                                             50%                  75%  \
# time                        2022-06-10 12:00:00  2024-02-28 18:00:00
# temperature_2m_max                         34.1                 38.4
# temperature_2m_min                         25.8                 30.0
# temperature_2m_mean                       29.65                 33.8
# apparent_temperature_max                   35.7                 42.0
# apparent_temperature_min                   28.1                 34.9
# precipitation_sum                           0.0                  0.0
# rain_sum                                    0.0                  0.0
# snowfall_sum                                0.0                  0.0
# precipitation_hours                         0.0                  0.0
# windspeed_10m_max                          22.6                 26.5
# windgusts_10m_max                          38.5                 43.6
# winddirection_10m_dominant                291.0                319.0
# shortwave_radiation_sum                   22.05                24.45
# et0_fao_evapotranspiration                 6.13                 7.28
# sunshine_duration                      39109.53           40167.4525
# pressure_msl_min                         1007.7               1013.6
# pressure_msl_max                         1011.4               1017.3
#
#                                             max          std
# time                        2025-11-18 00:00:00          NaN
# temperature_2m_max                         46.5     6.577466
# temperature_2m_min                         35.8     5.372844
# temperature_2m_mean                        39.1     5.581373
# apparent_temperature_max                   49.8     8.386427
# apparent_temperature_min                   42.4      8.05062
# precipitation_sum                          67.7     2.405945
# rain_sum                                   67.7     2.405945
# snowfall_sum                                0.0          0.0
# precipitation_hours                        21.0     1.215295
# windspeed_10m_max                          51.2     6.074824
# windgusts_10m_max                          81.0     8.054137
# winddirection_10m_dominant                360.0   128.395183
# shortwave_radiation_sum                   27.47     4.286053
# et0_fao_evapotranspiration                12.38     1.744508
# sunshine_duration                      44608.45  4698.046101
# pressure_msl_min                         1022.9     7.755879
# pressure_msl_max                         1026.3     8.044292

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------------------------------------------------------
# 6. STEP 4: QUANTIFYING RELATIONSHIPS (The Heat Map - The Real Magic)
#
# We quantify relationships with hard numbers using a Correlation Matrix [6].
# -----------------------------------------------------------------------------

print("--- Quantifying Relationships: Correlation Matrix and Heat Map ---")

# Calculate the correlation matrix for all variables
correlation_matrix = df.corr(numeric_only=True)

print("Raw Correlation Matrix (Hard Numbers):")
print(correlation_matrix)
# Check: Study_Hours vs Score should be near 0.6. Attendance_Rate vs Score should be near 0.8 [6].

# Visualize the correlation matrix using a Heat Map [6]
plt.figure(figsize=(8, 7))
# 'annot=True' displays the correlation score [6]
# 'cmap='coolwarm'' helps visualize strength (darker color = stronger relationship) [6]
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f",
            linewidths=.5, linecolor='black', cbar_kws={'label': 'Correlation Strength'})
plt.title('Heat Map of Key Variable Correlations', fontsize=14)
plt.show()
# Out:
# --- Quantifying Relationships: Correlation Matrix and Heat Map ---
# Raw Correlation Matrix (Hard Numbers):
#                             temperature_2m_max  temperature_2m_min  \
# temperature_2m_max                    1.000000            0.901542
# temperature_2m_min                    0.901542            1.000000
# temperature_2m_mean                   0.967762            0.976065
# apparent_temperature_max              0.963308            0.930478
# apparent_temperature_min              0.883595            0.956358
# precipitation_sum                    -0.085105           -0.067264
# rain_sum                             -0.085105           -0.067264
# snowfall_sum                               NaN                 NaN
# precipitation_hours                  -0.183115           -0.139356
# windspeed_10m_max                     0.012107            0.108143
# windgusts_10m_max                     0.073748            0.163137
# winddirection_10m_dominant           -0.133807            0.048027
# shortwave_radiation_sum               0.689449            0.627665
# et0_fao_evapotranspiration            0.803111            0.774304
# sunshine_duration                     0.504607            0.458446
# pressure_msl_min                     -0.859308           -0.881633
# pressure_msl_max                     -0.858225           -0.887973
# year                                  0.068805            0.029052
# month                                 0.327693            0.417659
#
#                             temperature_2m_mean  apparent_temperature_max  \
# temperature_2m_max                     0.967762                  0.963308
# temperature_2m_min                     0.976065                  0.930478
# temperature_2m_mean                    1.000000                  0.969794
# apparent_temperature_max               0.969794                  1.000000
# apparent_temperature_min               0.948883                  0.951451
# precipitation_sum                     -0.083982                 -0.068273
# rain_sum                              -0.083982                 -0.068273
# snowfall_sum                                NaN                       NaN
# precipitation_hours                   -0.173846                 -0.168348
# windspeed_10m_max                      0.046830                 -0.064926
# windgusts_10m_max                      0.100867                 -0.002849
# winddirection_10m_dominant            -0.030421                 -0.052533
# shortwave_radiation_sum                0.675778                  0.676861
# et0_fao_evapotranspiration             0.806955                  0.711040
# sunshine_duration                      0.499264                  0.503451
# pressure_msl_min                      -0.892254                 -0.884887
# pressure_msl_max                      -0.896252                 -0.887560
# year                                   0.039804                  0.089032
# month                                  0.405326                  0.378290
#
#                             apparent_temperature_min  precipitation_sum  \
# temperature_2m_max                          0.883595          -0.085105
# temperature_2m_min                          0.956358          -0.067264
# temperature_2m_mean                         0.948883          -0.083982
# apparent_temperature_max                    0.951451          -0.068273
# apparent_temperature_min                    1.000000          -0.076951
# precipitation_sum                          -0.076951           1.000000
# rain_sum                                   -0.076951           1.000000
# snowfall_sum                                     NaN                NaN
# precipitation_hours                        -0.158493           0.709166
# windspeed_10m_max                          -0.051439           0.138828
# windgusts_10m_max                           0.015041           0.127018
# winddirection_10m_dominant                  0.079422          -0.033795
# shortwave_radiation_sum                     0.618188          -0.163543
# et0_fao_evapotranspiration                  0.639560          -0.123881
# sunshine_duration                           0.467290          -0.241543
# pressure_msl_min                           -0.875858           0.027049
# pressure_msl_max                           -0.886109           0.039295
# year                                        0.068360           0.022246
# month                                       0.446788          -0.062406
#
#                             rain_sum  snowfall_sum  precipitation_hours  \
# temperature_2m_max         -0.085105           NaN            -0.183115
# temperature_2m_min         -0.067264           NaN            -0.139356
# temperature_2m_mean        -0.083982           NaN            -0.173846
# apparent_temperature_max   -0.068273           NaN            -0.168348
# apparent_temperature_min   -0.076951           NaN            -0.158493
# precipitation_sum           1.000000           NaN             0.709166
# rain_sum                    1.000000           NaN             0.709166
# snowfall_sum                     NaN           NaN                  NaN
# precipitation_hours         0.709166           NaN             1.000000
# windspeed_10m_max           0.138828           NaN             0.182038
# windgusts_10m_max           0.127018           NaN             0.169869
# winddirection_10m_dominant -0.033795           NaN            -0.018071
# shortwave_radiation_sum    -0.163543           NaN            -0.314180
# et0_fao_evapotranspiration -0.123881           NaN            -0.220780
# sunshine_duration          -0.241543           NaN            -0.384161
# pressure_msl_min            0.027049           NaN             0.102019
# pressure_msl_max            0.039295           NaN             0.118339
# year                        0.022246           NaN            -0.017228
# month                      -0.062406           NaN            -0.075562
#
#                             windspeed_10m_max  windgusts_10m_max  \
# temperature_2m_max                   0.012107           0.073748
# temperature_2m_min                   0.108143           0.163137
# temperature_2m_mean                  0.046830           0.100867
# apparent_temperature_max            -0.064926          -0.002849
# apparent_temperature_min            -0.051439           0.015041
# precipitation_sum                    0.138828           0.127018
# rain_sum                             0.138828           0.127018
# snowfall_sum                              NaN                NaN
# precipitation_hours                  0.182038           0.169869
# windspeed_10m_max                    1.000000           0.905429
# windgusts_10m_max                    0.905429           1.000000
# winddirection_10m_dominant           0.049314           0.103634
# shortwave_radiation_sum              0.083921           0.173107
# et0_fao_evapotranspiration           0.353108           0.392591
# sunshine_duration                   -0.016926           0.058371
# pressure_msl_min                    -0.104798          -0.176751
# pressure_msl_max                    -0.090724          -0.164492
# year                                -0.222743          -0.069959
# month                               -0.211276          -0.249767
#
#                             winddirection_10m_dominant  \
# temperature_2m_max                           -0.133807
# temperature_2m_min                            0.048027
# temperature_2m_mean                          -0.030421
# apparent_temperature_max                     -0.052533
# apparent_temperature_min                      0.079422
# precipitation_sum                            -0.033795
# rain_sum                                     -0.033795
# snowfall_sum                                       NaN
# precipitation_hours                          -0.018071
# windspeed_10m_max                             0.049314
# windgusts_10m_max                             0.103634
# winddirection_10m_dominant                    1.000000
# shortwave_radiation_sum                       0.099721
# et0_fao_evapotranspiration                   -0.044517
# sunshine_duration                             0.115509
# pressure_msl_min                             -0.068523
# pressure_msl_max                             -0.081908
# year                                          0.054525
# month                                        -0.046052
#
#                             shortwave_radiation_sum  \
# temperature_2m_max                         0.689449
# temperature_2m_min                         0.627665
# temperature_2m_mean                        0.675778
# apparent_temperature_max                   0.676861
# apparent_temperature_min                   0.618188
# precipitation_sum                         -0.163543
# rain_sum                                  -0.163543
# snowfall_sum                                    NaN
# precipitation_hours                       -0.314180
# windspeed_10m_max                          0.083921
# windgusts_10m_max                          0.173107
# winddirection_10m_dominant                 0.099721
# shortwave_radiation_sum                    1.000000
# et0_fao_evapotranspiration                 0.798031
# sunshine_duration                          0.849668
# pressure_msl_min                          -0.729046
# pressure_msl_max                          -0.740882
# year                                       0.028758
# month                                     -0.084922
#
#                             et0_fao_evapotranspiration  sunshine_duration  \
# temperature_2m_max                            0.803111           0.504607
# temperature_2m_min                            0.774304           0.458446
# temperature_2m_mean                           0.806955           0.499264
# apparent_temperature_max                      0.711040           0.503451
# apparent_temperature_min                      0.639560           0.467290
# precipitation_sum                            -0.123881          -0.241543
# rain_sum                                     -0.123881          -0.241543
# snowfall_sum                                       NaN                NaN
# precipitation_hours                          -0.220780          -0.384161
# windspeed_10m_max                             0.353108          -0.016926
# windgusts_10m_max                             0.392591           0.058371
# winddirection_10m_dominant                   -0.044517           0.115509
# shortwave_radiation_sum                       0.798031           0.849668
# et0_fao_evapotranspiration                    1.000000           0.611891
# sunshine_duration                             0.611891           1.000000
# pressure_msl_min                             -0.757215          -0.511146
# pressure_msl_max                             -0.757635          -0.529231
# year                                         -0.073297           0.024262
# month                                         0.063421           0.019003
#
#                             pressure_msl_min  pressure_msl_max      year  \
# temperature_2m_max                 -0.859308         -0.858225  0.068805
# temperature_2m_min                 -0.881633         -0.887973  0.029052
# temperature_2m_mean                -0.892254         -0.896252  0.039804
# apparent_temperature_max           -0.884887         -0.887560  0.089032
# apparent_temperature_min           -0.875858         -0.886109  0.068360
# precipitation_sum                   0.027049          0.039295  0.022246
# rain_sum                            0.027049          0.039295  0.022246
# snowfall_sum                             NaN               NaN       NaN
# precipitation_hours                 0.102019          0.118339 -0.017228
# windspeed_10m_max                  -0.104798         -0.090724 -0.222743
# windgusts_10m_max                  -0.176751         -0.164492 -0.069959
# winddirection_10m_dominant         -0.068523         -0.081908  0.054525
# shortwave_radiation_sum            -0.729046         -0.740882  0.028758
# et0_fao_evapotranspiration         -0.757215         -0.757635 -0.073297
# sunshine_duration                  -0.511146         -0.529231  0.024262
# pressure_msl_min                    1.000000          0.995968 -0.034673
# pressure_msl_max                    0.995968          1.000000 -0.042156
# year                               -0.034673         -0.042156  1.000000
# month                              -0.164037         -0.179131 -0.040234
#
#                                month
# temperature_2m_max          0.327693
# temperature_2m_min          0.417659
# temperature_2m_mean         0.405326
# apparent_temperature_max    0.378290
# apparent_temperature_min    0.446788
# precipitation_sum          -0.062406
# rain_sum                   -0.062406
# snowfall_sum                     NaN
# precipitation_hours        -0.075562
# windspeed_10m_max          -0.211276
# windgusts_10m_max          -0.249767
# winddirection_10m_dominant -0.046052
# shortwave_radiation_sum    -0.084922
# et0_fao_evapotranspiration  0.063421
# sunshine_duration           0.019003
# pressure_msl_min           -0.164037
# pressure_msl_max           -0.179131
# year                       -0.040234
# month                       1.000000
