# %% [markdown]
# <a href="https://colab.research.google.com/github/raheelarif86/AI_Training_November25/blob/main/Copy_of_nov16_day0_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 Getting Started with Python

# %%
#Video 1
#Youtube Playlist https://www.youtube.com/playlist?list=PLkT-YdCzItPE5yzyRnN_BIj-6IMu-ezBT

from IPython.display import HTML

HTML("""
<iframe width="560" height="315" src="https://www.youtube.com/embed/UujIwmkROf0?si=uPsQ-MVgKO1tjrf1" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/UujIwmkROf0?si=uPsQ-MVgKO1tjrf1" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("ENEC 11111111111")
# Out:
# ENEC 11111111111

# %% [markdown]
# Create a beginner's plan to learn Python from scratch.

# %% [markdown]
# # 2  DATA type
#
# ### Subtask:
# Start with fundamental concepts like variables, data types, and basic operations.

# %% [markdown]
# **Reasoning**:
# The subtask requires demonstrating fundamental Python concepts like variables, data types, basic operations, printing, and comments. A single code block can cover all these aspects.

# %% [markdown]
# Youtube Playlist
# https://www.youtube.com/playlist?list=PLkT-YdCzItPE5yzyRnN_BIj-6IMu-ezBT

# %%
#Video 2

from IPython.display import HTML

HTML("""
<iframe width="560" height="315" src="https://www.youtube.com/embed/KfisebjUuUM?si=LSVALY9lVOFeSZUH" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/KfisebjUuUM?si=LSVALY9lVOFeSZUH" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
# Step 1: Define variables of different data types
integer_var = 100
float_var = 3.1477
string_var = "Hello, ENEC"
boolean_var = True

# Step 2: Perform basic arithmetic operations
sum_result = integer_var + 5
difference_result = integer_var - 3
product_result = integer_var * 2
division_result = float_var / 2

# Step 3: Experiment with different ways to print output
print("Integer variable:", integer_var)
print("Float variable: " + str(float_var)) # Concatenation
print(f"String static variable ENEC CIO Team: {string_var}") # f-string
print(f"Boolean variable: {boolean_var}")

print(f"\nSum: {sum_result}")
print(f"Difference: {difference_result}")
print(f"Product: {product_result}")
print(f"Division: {division_result}")

# Step 4: Explore the concept of comments
# This is a single-line comment
"""
This is a multi-line comment
It can span across multiple lines
"""
# Out:
# Integer variable: 100
# Float variable: 3.1477
# String static variable ENEC CIO Team: Hello, ENEC
# Boolean variable: True
#
# Sum: 105
# Difference: 97
# Product: 200
# Division: 1.57385
# '\nThis is a multi-line comment\nIt can span across multiple lines\n'

# %%
string_var
# Out:
# 'Hello, ENEC'

# %%
print(f"String static variable ENEC 1234511111 CIO AI: {string_var}") # f-string
# Out:
# String static variable ENEC 1234511111 CIO AI: Hello, ENEC

# %%
# Basic f-string
name = "Balqees"
greeting = f"Hello ENEC, {name}!"
print(greeting)

# Embedding expressions
x = 10
y = 5
sum_result = f"The sum of {x} and {y} is {x + y}."
print(sum_result)

# Formatting
pi = 3.14159
formatted_pi = f"The value of pi is approximately {pi:.2f}." # Format to 2 decimal places
print(formatted_pi)

# Using f-strings with dictionaries
person = {"name": "Alice", "age": 30}
person_info = f"Name: {person['name']}, Age: {person['age']}."
print(person_info)

# Using f-strings with lists
fruits = ["apple", "banana", "cherry"]
fruit_list = f"My favorite fruits are: {', '.join(fruits)}."
print(fruit_list)

# Multiline f-strings
multiline_string = f"""
This is a multiline
f-string.
It can span multiple lines
and include variables like {name}.
"""
print(multiline_string)
# Out:
# Hello ENEC, Balqees!
# The sum of 10 and 5 is 15.
# The value of pi is approximately 3.14.
# Name: Alice, Age: 30.
# My favorite fruits are: apple, banana, cherry.
#
# This is a multiline
# f-string.
# It can span multiple lines
# and include variables like Balqees.

# %%
string_var
# Out:
# 'Hello, Abdulrahman Alzaabi!'

# %%
print(f"ENEC {string_var}")
# Out:
# ENEC Hello, Abdulrahman Alzaabi!

# %% [markdown]
# # 3 Data structures
#
# ### Subtask:
# Explore built-in data structures like lists, tuples, dictionaries, and sets.

# %% [markdown]
# **Reasoning**:
# The instructions require creating and manipulating lists, tuples, dictionaries, and sets. This involves creating instances of each data structure and performing basic operations like accessing elements, slicing, demonstrating immutability, adding, and removing elements. A single code block can encompass all these steps.

# %%
#Video 3

from IPython.display import HTML

HTML("""
<iframe width="560" height="315" src="https://www.youtube.com/embed/bPE8v8VdGB4?si=U3N5NqUn7-OpWFqJ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/bPE8v8VdGB4?si=U3N5NqUn7-OpWFqJ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ![Screenshot 2023-04-13 172446-Q4g0MpfxjK.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![download (41).png](data:image/png;base64,...)

# %% [markdown]
# 1. Lists – Ordered, Mutable Collections
# Lists are Python’s primary sequence type for storing ordered collections of items and can contain mixed data types. Lists are mutable, meaning their content can be changed after creation.

# %%
# 1. Creating a list (using square brackets [])
numbers = [1, 2, 3, 4]   # list of integers
mixed = [1, "two", 3.0, False]  # list can contain mixed data types

print("Initial List (numbers):", numbers)

# 2. Indexing (Accessing elements, index starts at 0)
print("First element (index 0):", numbers[0])        # 1
print("Last element (negative index):", numbers[-1]) # 4

# 3. Mutability (Modifying elements)
# Change the second element (index 1) from 2 to 99
numbers[1] = 99
print("List after modification (index 1 is 99):", numbers)

# 4. Adding/Removing elements
numbers.append(5)   # adds 5 to the end
print("List after append(5):", numbers)

# since 2 is no longer in the list, remove an element that exists, e.g. 99
numbers.remove(99)
print("List after remove(99):", numbers)

# 5. Common operations: Length and Slicing
print("Length of list:", len(numbers))
print("Sublist (slicing numbers[1:3]):", numbers[1:3])
# Out:
# Initial List (numbers): [1, 2, 3, 4]
# First element (index 0): 1
# Last element (negative index): 4
# List after modification (index 1 is 99): [1, 99, 3, 4]
# List after append(5): [1, 99, 3, 4, 5]
# List after remove(99): [1, 3, 4, 5]
# Length of list: 4
# Sublist (slicing numbers[1:3]): [3, 4]

# %% [markdown]
# 2. Tuples – Ordered, Immutable Collections
# Tuples are similar to lists as they are ordered sequences of elements. However, the key difference is that tuples are immutable; once created, their elements cannot be changed or replaced. Tuples are often used for data that shouldn't change (like coordinates) or for grouping heterogeneous data.

# %%
# 1. Creating a tuple (using parentheses or just commas)
trio = ("Alice", 30, 5.5) # tuple with a string, int, and float [10]
no_paren = 1, 2, 3 # tuple packing without parentheses [10]

print("Initial Tuple (trio):", trio)

# 2. Accessing elements (similar to lists)
print("Accessing the first element:", trio)

# 3. Immutability Implication
# NOTE: The following line, if executed, would raise an error (Immutability error): [8]
# trio = "Bob"
# print(trio) # To change a tuple, you must create a new one [8].

# 4. Tuple Unpacking (A neat feature)
name, age, height = trio
print(f"Unpacked variables: Name={name}, Age={age}")
# Out:
# Initial Tuple (trio): ('Alice', 30, 5.5)
# Accessing the first element: ('Alice', 30, 5.5)
# Unpacked variables: Name=Alice, Age=30

# %% [markdown]
# 3. Sets – Unordered Collections of Unique Elements
# Sets store unique values without any particular order, analogous to a mathematical set. They are useful for eliminating duplicates or performing fast membership checks. Sets are mutable.

# %%
# 1. Creating a set (using curly braces)
# Duplicates (2) are removed during creation [11, 13]
nums = {1, 2, 2, 3}
print("Initial Set (nums):", nums) # Output will be {1, 2, 3}

# Note: The order is not preserved in a set [13]
fruits = {"apple", "banana", "cherry"}
print("Initial Set (fruits):", fruits)

# 2. Adding and Removing elements (Sets are mutable)
fruits.add("orange")
print("Set after adding 'orange':", fruits)
fruits.remove("banana")
print("Set after removing 'banana':", fruits)

# 3. Set Operations (Mathematical operations) [14]
evens = {2, 4, 6, 8}
odds = {1, 3, 5, 7, 9}
others = {4, 5, 6}

# Union (set1 | set2) - combining unique elements [14]
print("Union (evens | odds):", evens | odds)

# Intersection (&) - finding common elements [14]
print("Intersection (evens & others):", evens & others)

# Difference (-) [14]
print("Difference (odds - {3,7}):", odds - {3, 7})

# 4. Membership Test (Very fast lookup) [14]
print("Is 'apple' in fruits?", "apple" in fruits)
# Out:
# Initial Set (nums): {1, 2, 3}
# Initial Set (fruits): {'banana', 'cherry', 'apple'}
# Set after adding 'orange': {'orange', 'banana', 'cherry', 'apple'}
# Set after removing 'banana': {'orange', 'cherry', 'apple'}
# Union (evens | odds): {1, 2, 3, 4, 5, 6, 7, 8, 9}
# Intersection (evens & others): {4, 6}
# Difference (odds - {3,7}): {1, 5, 9}
# Is 'apple' in fruits? True

# %% [markdown]
# 4. Dictionaries – Key-Value Mappings
# Dictionaries (dict) store mappings from unique, immutable keys to values. They are incredibly important for representing structured data and performing fast lookups by key. Dictionaries are mutable.

# %%
# 1. Creating a dictionary (using curly braces with key:value pairs)
person = {
    "name": "Alice",
    "age": 25,
    "city": "Dubai"
} # [15, 19]

# Another example: Country capitals [16]
capitals = {"UAE": "Abu Dhabi", "France": "Paris", "Japan": "Tokyo"}

print("Initial Dictionary (person):", person)

# 2. Accessing values (using the key)
print("Person's name:", person["name"]) # person["name"] gives "Alice" [19]
print("Capital of France:", capitals["France"]) # outputs "Paris" [16]

# 3. Adding/Modifying entries (Dictionaries are mutable)
# Updating an existing value [18]
person["age"] = 26
print("Age after modification:", person["age"])

# Adding a new entry [18]
person["email"] = "alice@example.com"
print("Dictionary after adding email:", person)

# 4. Iteration (Looping through keys and values) [18]
print("\nIterating through the person dictionary:")
for key in person:
    # Print key and its corresponding value [18]
    print(key, "->", person[key])
# Out:
# Initial Dictionary (person): {'name': 'Alice', 'age': 25, 'city': 'Dubai'}
# Person's name: Alice
# Capital of France: Paris
# Age after modification: 26
# Dictionary after adding email: {'name': 'Alice', 'age': 26, 'city': 'Dubai', 'email': 'alice@example.com'}
#
# Iterating through the person dictionary:
# name -> Alice
# age -> 26
# city -> Dubai
# email -> alice@example.com

# %% [markdown]
# # 4 Control flow
#
# ### Subtask:
# Learn about conditional statements (if-else) and loops (for, while) to control the execution of your code.

# %% [markdown]
# **Reasoning**:
# The subtask requires demonstrating conditional statements and loops. I will write a single code block that includes examples of if-elif-else, for loops, and while loops with comments explaining each part.

# %%
#video 4
from IPython.display import HTML

HTML("""
<iframe width="560" height="315" src="https://www.youtube.com/embed/qDgkeETAiNQ?si=0tHrsuKEb_qovxGj" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/qDgkeETAiNQ?si=0tHrsuKEb_qovxGj" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
# 1. Demonstrate conditional statements (if-elif-else)

# Example with numerical values
temperature = 20

if temperature > 30:
  print("It's a hot day!")
elif temperature >= 20:
  print("It's a pleasant day.")
else:
  print("It's a bit chilly.")

# Example with string values
color = "blue"

if color == "red":
  print("The color is red.")
elif color == "blue":
  print("The color is blue.")
else:
  print("The color is neither red nor blue.")


# 2. Create a for loop
fruits = ["apple", "banana", "cherry"]

print("\nIterating through the fruits list:")
for fruit in fruits:
  print(fruit)


# 3. Write a while loop
count = 0

print("\nCounting with a while loop:")
while count < 5:
  print(count)
  count += 1 # Increment count to eventually break the loop
# Out:
# It's a pleasant day.
# The color is blue.
#
# Iterating through the fruits list:
# apple
# banana
# cherry
#
# Counting with a while loop:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # 5 Functions
#
# ### Subtask:
# Understand how to define and use functions to organize your code and make it reusable.

# %% [markdown]
# **Reasoning**:
# The instructions require defining and calling functions. I will define the `greet`, `add_numbers`, and `calculate_area` functions and then call them as specified.

# %%
#video 5
from IPython.display import HTML

HTML("""
<iframe width="560" height="315" src="https://www.youtube.com/embed/0qAtCwvredA?si=vnQiGfsjpop5enGb" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/0qAtCwvredA?si=vnQiGfsjpop5enGb" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
# 1. Define a simple function named greet
def greet(name):
  """Greets a person with a given name."""
  print(f"Hello ENEC, {name}!")

# 2. Call the greet function with your name
greet("Karthick Manoharan")

# 3. Define a function named add_numbers
def add_numbers(num1, num2):
  """Adds two numbers and returns their sum."""
  return num1 + num2

# 4. Call the add_numbers function with two numbers and print the returned result
result_sum = add_numbers(100, 100)
print(f"The sum of 100 and 100 is: {result_sum}")

# 5. Define a function named calculate_area with default arguments
def calculate_area(length=1, width=1):
  """Calculates the area of a rectangle with optional default values."""
  return length * width

# 6. Call the calculate_area function without arguments and print the result
area_default = calculate_area()
print(f"Area with default values: {area_default}")

# 7. Call the calculate_area function with specific length and width values and print the result
area_specific = calculate_area(length=10, width=5)
print(f"Area with specific values (10x5): {area_specific}")
# Out:
# Hello ENEC, Karthick Manoharan!
# The sum of 100 and 100 is: 200
# Area with default values: 1
# Area with specific values (10x5): 50

# %% [markdown]
# # 6 File Handling

# %% [markdown]
# 1. The Classic, Manual Three-Step Process (Risky Way)
# This method requires manually opening the file, performing the operation, and manually closing the file using f.close(). If you forget the closing step, your data might not be saved properly, or the file can be left in a "weird state".
#
# A. Manual Reading Example
# This example demonstrates the core structure for reading, where the file handle must be explicitly closed:

# %%
#video 6
from IPython.display import HTML

HTML("""
<iframe width="560" height="315" src="https://www.youtube.com/embed/BydhnCw0DWw?si=eTpl0-YV-9LK6Z8W" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/BydhnCw0DWw?si=eTpl0-YV-9LK6Z8W" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
# Step 1: Open the file ("data.txt" is the example filename discussed)
# 'r' mode is used for reading [1, 3]
file_handle = open("data.txt", "r")

# Step 2: Do the thing (e.g., read the contents)
# (The exact read method was not specified, but f.read() is common)
# file_contents = file_handle.read()

# Step 3: Crucially, you must remember to call f.close() [3]
file_handle.close()

# %% [markdown]
# B. Manual Writing Example
# This demonstrates writing data in write mode (w), which is destructive (it wipes the file clean if it already exists):

# %%
# Step 1: Open the file in write mode ('w') [1, 3]
# Note: If output.txt exists, 'w' will wipe it clean [3]
file_handle = open("output.txt", "w")

# Step 2: Do the thing (e.g., use the write method) [3]
file_handle.write("Hello, World!")

# Step 3: The manual close call is mandatory [3]
# If you forget this step, your data might not even get saved properly [3]
file_handle.close()

# %% [markdown]
# 2. The Modern, Pythonic Way (with Statement)
# The with statement is the established, correct, professional way to work with files because it guarantees that Python automatically closes the file for you, even if your code crashes.
# A. Pythonic Reading Example
# This demonstrates looping through a file line by line using the with statement:

# %%
# The magic of the 'with' statement [2]
# Python automatically closes the file the moment the indented block is done [2]
with open("data.txt", "r") as file: # 'file' is the temporary name/handle used [2]

    # Loop through the file line by line [2]
    for line in file:
        # Use .strip() to clean up the line, getting rid of invisible spaces or new lines [2]
        print(line.strip())

# Notice what is missing: No manual file closing [2]
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# B. Pythonic Writing Example
# This demonstrates writing a list of data to a file in write mode (w), ensuring the file is safely saved and closed:
#
# Note on Modes:
# • R is for read.
# • W is for write (destructive).
# • A is for append (adds new stuff to the end, much safer than 'w')

# %%
# 1. Start with the data (a list of numbers, as discussed in the source) [4]
numbers_list = [1,2,3,4]

# 2. Open the file in write mode ('w'), giving it the handle 'f' inside the block [4]
with open("results.txt", "w") as f:

    # Loop through our list [4]
    for num in numbers_list:
        # Convert each number to a string (f.write requires a string) [4]
        data_to_write = str(num) + "\n" # Added newline for readability

        # Write the string to the file using the write method [4]
        f.write(data_to_write)

# When the loop finishes and the indented block is left,
# the file is automatically saved and closed

# %% [markdown]
# You will find the files on right panel of colab notebook
#
# ![image.png](data:image/png;base64,...)
