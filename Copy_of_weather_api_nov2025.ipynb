# %% [markdown]
# <a href="https://colab.research.google.com/github/raheelarif86/AI_Training_November25/blob/main/Copy_of_weather_api_nov2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
response = requests.get("https://api.openweathermap.org/data/2.5/weather?q=Abu%20dhabi&appid=79007029562c2ab46617d801d8018750&units=metric")
print(response.json())
# Out:
# {'coord': {'lon': 54.3667, 'lat': 24.4667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 24.01, 'feels_like': 24.14, 'temp_min': 22.06, 'temp_max': 24.01, 'pressure': 1019, 'humidity': 64, 'sea_level': 1019, 'grnd_level': 1019}, 'visibility': 7000, 'wind': {'speed': 2.06, 'deg': 130}, 'clouds': {'all': 100}, 'dt': 1763442001, 'sys': {'type': 1, 'id': 7533, 'country': 'AE', 'sunrise': 1763433627, 'sunset': 1763472913}, 'timezone': 14400, 'id': 292968, 'name': 'Abu Dhabi', 'cod': 200}

# %%
import requests

def get_weather(city):
   url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"

   try:
       response= requests.get(url)
       weather_data = response.json()

       temperature = weather_data["main"]["temp"]
       humidity = weather_data["main"]["humidity"]
       max_temp = weather_data["main"]["temp_max"]
       min_temp = weather_data["main"]["temp_min"]
       wind_speed = weather_data["wind"]["speed"]
       sea_level = weather_data["main"]["sea_level"]
       clouds = weather_data["clouds"]["all"]


       print(f"Weather in {city}:")
       print(f"Temperature {temperature}°C:")
       print(f"Humidity : {humidity}%")
       print(f"Max Temperature: {max_temp}°C:")
       print(f"Min Temperature: {min_temp}°C:")
       print(f"Wind Speed: {wind_speed} m/s:")
       print (f"Sea Level: {sea_level}")
       print (f"Clouds: {clouds}")

   except requests.exceptions.RequestException:
        print("Error occured")


#usage
city_name = input("Enter the name of city:")
get_weather(city_name)
# Out:
# Enter the name of city:abbottabad
# Weather in abbottabad:
# Temperature 17.37°C:
# Humidity : 23%
# Max Temperature: 17.37°C:
# Min Temperature: 17.37°C:
# Wind Speed: 1.25 m/s:
# Sea Level: 1020
# Clouds: 1

# %%
pip install gradio

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        return f"The current temperature in {city} is {temp}°C with {description}."
    else:
        return "Sorry, I couldn't find weather information for that city."

iface = gr.Interface(fn=get_weather, inputs="text", outputs="text")
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3b0759657cc4b58f27.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3b0759657cc4b58f27.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        return f"The current temperature in {city} is {temp}°C with {description}."
    else:
        return "Sorry, I couldn't find weather information for that city."

with gr.Blocks(theme=gr.themes.Soft()) as iface:
    gr.Markdown(
        """
        <div style='text-align: center;'>
            <h1 style='margin-bottom: 0;'>🌅 Raheel Weather Bot</h1>
            <p style='font-size: 18px; margin-top: 4px;'>Your simple city weather assistant</p>
        </div>
        """
    )

    with gr.Group():
        with gr.Row():
            city_input = gr.Textbox(label="Enter City Name", placeholder="e.g., Dubai", scale=3)
            submit_btn = gr.Button("Get Weather", variant="primary")

        weather_output = gr.Textbox(label="Weather Report")

    submit_btn.click(fn=get_weather, inputs=city_input, outputs=weather_output)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b17c716e4f5f3fe2aa.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b17c716e4f5f3fe2aa.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        return f"The current temperature in {city} is {temp}°C with {description}."
    else:
        return "Sorry, I couldn't find weather information for that city."

with gr.Blocks(theme=gr.themes.Soft(), css="""
@keyframes rise {
    0% { transform: translateY(20px); opacity: 0.4; }
    50% { transform: translateY(-5px); opacity: 1; }
    100% { transform: translateY(0); opacity: 1; }
}

.animated-sun {
    font-size: 65px;
    animation: rise 3s ease-in-out infinite alternate;
}
""") as iface:

    gr.Markdown(
        """
        <div style='text-align: center; margin-bottom: 10px;'>
            <div class="animated-sun">🌅</div>
            <h1 style='margin-bottom: 0;'>Raheel Weather Bot</h1>
            <p style='font-size: 18px; margin-top: 4px;'>Get instant weather updates for any city 🌤</p>
        </div>
        """
    )

    with gr.Group():
        with gr.Row():
            city_input = gr.Textbox(label="Enter City", placeholder="e.g., Dubai", scale=3)
            submit_btn = gr.Button("Check Weather", variant="primary")

        weather_output = gr.Textbox(label="Weather Report")

    submit_btn.click(fn=get_weather, inputs=city_input, outputs=weather_output)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://fbce3f4131fab06f87.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fbce3f4131fab06f87.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
